# %%
import numpy as np
import os
import pandas as pd
import soundfile as sf

import matplotlib.pyplot as plt
import matplotlib.ticker as tick
from matplotlib import colors
from matplotlib.patches import Rectangle

import scipy.io.wavfile as wav
import datetime as dt
from pathlib import Path

from torch import multiprocessing
from tqdm import tqdm

# %%
import sys

# append the path of the
# parent directory
sys.path.append('..')
sys.path.append('../src/')
sys.path.append('../src/models/bat_call_detector/batdetect2/')

# %%
from src.cfg import get_config
from src.pipeline import pipeline
import src.batdt2_pipeline as batdetect2_pipeline

# %%
dirpath = f"{Path.home()}/Documents/UBNA/Symposium/Recordings/recover-20221018/UBNA_099"

recover_folder = dirpath.split('/')[-2]
audiomoth_folder = dirpath.split('/')[-1]
audiomoth_unit = audiomoth_folder.split('_')[-1]

save_dir = f'../output_dir/{recover_folder}/{audiomoth_folder}'

detfile_name = f'batdetect2_pipeline__{recover_folder}_{audiomoth_unit}'

[dirpath, save_dir, detfile_name]
# Out:
# ['/Users/adityakrishna/Documents/UBNA/Symposium/Recordings/recover-20221018/UBNA_099',
#  '../output_dir/recover-20221018/UBNA_099',
#  'batdetect2_pipeline__recover-20221018_099']

# %%
## Each file in directory has own set of detections from 0 to file_length
## Audio file corresponding to any detection is stored in .csv output's 'input_file' column

# batdetect2_pipeline.run_pipeline(dirpath, f"{detfile_name}.csv", save_dir, f'../output/tmp')
# Out:
# 100%|██████████| 3780/3780 [5:32:52<00:00,  5.28s/it]
#     start_time   end_time  low_freq  high_freq  detection_confidence  \
# 0     864.8815   864.8887   40078.0    54405.0                 0.648
# 1     864.9665   864.9710   41796.0    51690.0                 0.525
# 2     865.0315   865.0366   41796.0    50058.0                 0.540
# 3     865.1535   865.1594   40937.0    53686.0                 0.760
# 4     865.2345   865.2395   40937.0    56544.0                 0.587
# ..         ...        ...       ...        ...                   ...
# 14   1340.9425  1340.9503   46953.0    63630.0                 0.575
# 15   1341.0585  1341.0649   44375.0    73322.0                 0.529
# 16   1341.3325  1341.3401   43515.0    64806.0                 0.612
# 17   1341.8305  1341.8408   46953.0    62214.0                 0.511
# 18   1342.0905  1342.0991   44375.0    64562.0                 0.560
#
#            event           input_file
# 0   Echolocation  20220820_033000.WAV
# 1   Echolocation  20220820_033000.WAV
# 2   Echolocation  20220820_033000.WAV
# 3   Echolocation  20220820_033000.WAV
# 4   Echolocation  20220820_033000.WAV
# ..           ...                  ...
# 14  Echolocation  20221017_100000.WAV
# 15  Echolocation  20221017_100000.WAV
# 16  Echolocation  20221017_100000.WAV
# 17  Echolocation  20221017_100000.WAV
# 18  Echolocation  20221017_100000.WAV
#
# [91919 rows x 7 columns]

# %%
batdetect2_pipeline.plot_dets_as_activity_grid(dirpath, detfile_name, save_dir)
