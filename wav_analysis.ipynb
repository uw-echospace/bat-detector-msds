# %%
buzz_path = '/Users/kirsteenng/Desktop/UW/DATA 590/wav_data/20210910_030000_time2303_LFbuzz.wav'
social_path = '/Users/kirsteenng/Desktop/UW/DATA 590/wav_data/20210910_070000_social_calls.wav'
buzz_path2 = '/Users/kirsteenng/Desktop/UW/DATA 590/wav_data/20210921_030000_time1054_LFbuzz_varyFreq.wav'

# %%
# Import libraries
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %%
# Helper function
def plotwav(path):

    samplingFrequency, signalData = wavfile.read(path)

    plt.title('Spectrogram')    
    Pxx, freqs, bins, im = plt.specgram(signalData,Fs=samplingFrequency,NFFT=400 )
    plt.xlabel('Time')
    plt.ylabel('Frequency')
    #plt.xlim(left=0,right=17)

    plt.show()

# %%
plotwav("/Users/kirsteenng/Desktop/UW/DATA 590/individual spectrogram/hf_20221012_030000.WAV20.wav")

# %%
plotwav(social_path)
# Out:
# /var/folders/zd/c28nct6s5454q__hl8mn2xbc0000gn/T/ipykernel_5853/2576154569.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplingFrequency, signalData = wavfile.read(path)

# %%
plotwav(buzz_path2)
# Out:
# /var/folders/zd/c28nct6s5454q__hl8mn2xbc0000gn/T/ipykernel_5853/2576154569.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   samplingFrequency, signalData = wavfile.read(path)
